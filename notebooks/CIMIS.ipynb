# %%
import pandas as pd

# %%
alameda_county = pd.read_csv('/content/drive/MyDrive/Data Science Project/Data Science Project/Datasets/CIMIS/CIMIS Daily Report Alameda County.csv')
alpine_county = pd.read_csv('/content/drive/MyDrive/Data Science Project/Data Science Project/Datasets/CIMIS/CIMIS Daily Report Alpine County.csv')
amador_county = pd.read_csv('/content/drive/MyDrive/Data Science Project/Data Science Project/Datasets/CIMIS/CIMIS Daily Report Amador County.csv')
butte_county = pd.read_csv('/content/drive/MyDrive/Data Science Project/Data Science Project/Datasets/CIMIS/CIMIS Daily Report Butte County.csv')
colusa_county = pd.read_csv('/content/drive/MyDrive/Data Science Project/Data Science Project/Datasets/CIMIS/CIMIS Daily Report Colusa County.csv')
contra_costa_county = pd.read_csv('/content/drive/MyDrive/Data Science Project/Data Science Project/Datasets/CIMIS/CIMIS Daily Report Contra Costa County.csv')
del_norte_county = pd.read_csv('/content/drive/MyDrive/Data Science Project/Data Science Project/Datasets/CIMIS/CIMIS Daily Report Del Norte County.csv')
el_dorado_county = pd.read_csv('/content/drive/MyDrive/Data Science Project/Data Science Project/Datasets/CIMIS/CIMIS Daily Report El Dorado County.csv')
fresno_county = pd.read_csv('/content/drive/MyDrive/Data Science Project/Data Science Project/Datasets/CIMIS/CIMIS Daily Report Fresno County.csv')
humboldt_county = pd.read_csv('/content/drive/MyDrive/Data Science Project/Data Science Project/Datasets/CIMIS/CIMIS Daily Report Humboldt County.csv')
imperial_county = pd.read_csv('/content/drive/MyDrive/Data Science Project/Data Science Project/Datasets/CIMIS/CIMIS Daily Report Imperial County.csv')
inyo_county = pd.read_csv('/content/drive/MyDrive/Data Science Project/Data Science Project/Datasets/CIMIS/CIMIS Daily Report Inyo County.csv')
kern_county = pd.read_csv('/content/drive/MyDrive/Data Science Project/Data Science Project/Datasets/CIMIS/CIMIS Daily Report Kern County.csv')
kings_county = pd.read_csv('/content/drive/MyDrive/Data Science Project/Data Science Project/Datasets/CIMIS/CIMIS Daily Report Kings County.csv')
lassen_county = pd.read_csv('/content/drive/MyDrive/Data Science Project/Data Science Project/Datasets/CIMIS/CIMIS Daily Report Lassen County.csv')
los_angeles_county = pd.read_csv('/content/drive/MyDrive/Data Science Project/Data Science Project/Datasets/CIMIS/CIMIS Daily Report Los Angeles County.csv')
marin_county = pd.read_csv('/content/drive/MyDrive/Data Science Project/Data Science Project/Datasets/CIMIS/CIMIS Daily Report Marin County.csv')
mendocino_county = pd.read_csv('/content/drive/MyDrive/Data Science Project/Data Science Project/Datasets/CIMIS/CIMIS Daily Report Mendocino County.csv')
modoc_county = pd.read_csv('/content/drive/MyDrive/Data Science Project/Data Science Project/Datasets/CIMIS/CIMIS Daily Report Modoc County.csv')
monterey_county = pd.read_csv('/content/drive/MyDrive/Data Science Project/Data Science Project/Datasets/CIMIS/CIMIS Daily Report Monterey County.csv')
napa_county = pd.read_csv('/content/drive/MyDrive/Data Science Project/Data Science Project/Datasets/CIMIS/CIMIS Daily Report Napa County.csv')
orange_county = pd.read_csv('/content/drive/MyDrive/Data Science Project/Data Science Project/Datasets/CIMIS/CIMIS Daily Report Orange County.csv')
placer_county = pd.read_csv('/content/drive/MyDrive/Data Science Project/Data Science Project/Datasets/CIMIS/CIMIS Daily Report Placer County.csv')
plumas_county = pd.read_csv('/content/drive/MyDrive/Data Science Project/Data Science Project/Datasets/CIMIS/CIMIS Daily Report Plumas County.csv')
riverside_county = pd.read_csv('/content/drive/MyDrive/Data Science Project/Data Science Project/Datasets/CIMIS/CIMIS Daily Report Riverside County.csv')
sacramento_county = pd.read_csv('/content/drive/MyDrive/Data Science Project/Data Science Project/Datasets/CIMIS/CIMIS Daily Report Sacramento County.csv')
san_benito_county = pd.read_csv('/content/drive/MyDrive/Data Science Project/Data Science Project/Datasets/CIMIS/CIMIS Daily Report San Benito County.csv')
san_bernardino_county = pd.read_csv('/content/drive/MyDrive/Data Science Project/Data Science Project/Datasets/CIMIS/CIMIS Daily Report San Bernardino County.csv')
san_diego_county = pd.read_csv('/content/drive/MyDrive/Data Science Project/Data Science Project/Datasets/CIMIS/CIMIS Daily Report San Diego County.csv')
san_joaquin_county = pd.read_csv('/content/drive/MyDrive/Data Science Project/Data Science Project/Datasets/CIMIS/CIMIS Daily Report San Joaquin County.csv')
san_luis_obispo_county = pd.read_csv('/content/drive/MyDrive/Data Science Project/Data Science Project/Datasets/CIMIS/CIMIS Daily Report San Luis Obispo County.csv')
san_mateo_county = pd.read_csv('/content/drive/MyDrive/Data Science Project/Data Science Project/Datasets/CIMIS/CIMIS Daily Report San Mateo County.csv')
santa_barbara_county = pd.read_csv('/content/drive/MyDrive/Data Science Project/Data Science Project/Datasets/CIMIS/CIMIS Daily Report Santa Barbara County.csv')
santa_clara_county = pd.read_csv('/content/drive/MyDrive/Data Science Project/Data Science Project/Datasets/CIMIS/CIMIS Daily Report Santa Clara County.csv')
santa_cruz_county = pd.read_csv('/content/drive/MyDrive/Data Science Project/Data Science Project/Datasets/CIMIS/CIMIS Daily Report Santa Cruz County.csv')
shasta_county =pd.read_csv('/content/drive/MyDrive/Data Science Project/Data Science Project/Datasets/CIMIS/CIMIS Daily Report Shasta County.csv')
siskiyou_county = pd.read_csv('/content/drive/MyDrive/Data Science Project/Data Science Project/Datasets/CIMIS/CIMIS Daily Report Siskiyou County.csv')
solano_county = pd.read_csv('/content/drive/MyDrive/Data Science Project/Data Science Project/Datasets/CIMIS/CIMIS Daily Report Solano County.csv')
sonoma_county = pd.read_csv('/content/drive/MyDrive/Data Science Project/Data Science Project/Datasets/CIMIS/CIMIS Daily Report Sonoma County.csv')
stanislaus_county = pd.read_csv('/content/drive/MyDrive/Data Science Project/Data Science Project/Datasets/CIMIS/CIMIS Daily Report Stanislaus County.csv')
sutter_county = pd.read_csv('/content/drive/MyDrive/Data Science Project/Data Science Project/Datasets/CIMIS/CIMIS Daily Report Sutter County.csv')
tehama_county = pd.read_csv('/content/drive/MyDrive/Data Science Project/Data Science Project/Datasets/CIMIS/CIMIS Daily Report Tehama County.csv')
tulare_county = pd.read_csv('/content/drive/MyDrive/Data Science Project/Data Science Project/Datasets/CIMIS/CIMIS Daily Report Tulare County.csv')
ventura_county = pd.read_csv('/content/drive/MyDrive/Data Science Project/Data Science Project/Datasets/CIMIS/CIMIS Daily Report Ventura County.csv')
yolo_county = pd.read_csv('/content/drive/MyDrive/Data Science Project/Data Science Project/Datasets/CIMIS/CIMIS Daily Report Yolo County.csv')
yuba_county = pd.read_csv('/content/drive/MyDrive/Data Science Project/Data Science Project/Datasets/CIMIS/CIMIS Daily Report Yuba County.csv')

# %%
alameda_county.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5479 entries, 0 to 5478
# Data columns (total 33 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Stn Id                5479 non-null   int64
#  1   Stn Name              5479 non-null   object
#  2   CIMIS Region          5479 non-null   object
#  3   Date                  5479 non-null   object
#  4   Jul                   5479 non-null   int64
#  5   ETo (in)              5479 non-null   float64
#  6   qc                    5479 non-null   object
#  7   Precip (in)           5360 non-null   float64
#  8   qc.1                  5479 non-null   object
#  9   Sol Rad (Ly/day)      5355 non-null   float64
#  10  qc.2                  5479 non-null   object
#  11  Avg Vap Pres (mBars)  5355 non-null   float64
#  12  qc.3                  5479 non-null   object
#  13  Max Air Temp (F)      5353 non-null   float64
#  14  qc.4                  5479 non-null   object
# ...

# %%
alameda = alameda_county[['Date', 'ETo (in)', 'Precip (in)', 'Sol Rad (Ly/day)', 'Avg Vap Pres (mBars)', 'Max Air Temp (F)', 'Min Air Temp (F)', 'Max Rel Hum (%)', 'Avg Wind Speed (mph)', 'Wind Run (miles)', 'Avg Soil Temp (F)']]
alpine = alpine_county[['Date', 'ETo (in)', 'Precip (in)', 'Sol Rad (Ly/day)', 'Avg Vap Pres (mBars)', 'Max Air Temp (F)', 'Min Air Temp (F)', 'Max Rel Hum (%)', 'Avg Wind Speed (mph)', 'Wind Run (miles)', 'Avg Soil Temp (F)']]
amador = amador_county[['Date', 'ETo (in)', 'Precip (in)', 'Sol Rad (Ly/day)', 'Avg Vap Pres (mBars)', 'Max Air Temp (F)', 'Min Air Temp (F)', 'Max Rel Hum (%)', 'Avg Wind Speed (mph)', 'Wind Run (miles)', 'Avg Soil Temp (F)']]
butte = butte_county[['Date', 'ETo (in)', 'Precip (in)', 'Sol Rad (Ly/day)', 'Avg Vap Pres (mBars)', 'Max Air Temp (F)', 'Min Air Temp (F)', 'Max Rel Hum (%)', 'Avg Wind Speed (mph)', 'Wind Run (miles)', 'Avg Soil Temp (F)']]
colusa = colusa_county[['Date', 'ETo (in)', 'Precip (in)', 'Sol Rad (Ly/day)', 'Avg Vap Pres (mBars)', 'Max Air Temp (F)', 'Min Air Temp (F)', 'Max Rel Hum (%)', 'Avg Wind Speed (mph)', 'Wind Run (miles)', 'Avg Soil Temp (F)']]
contra_costa_ = contra_costa_county[['Date', 'ETo (in)', 'Precip (in)', 'Sol Rad (Ly/day)', 'Avg Vap Pres (mBars)', 'Max Air Temp (F)', 'Min Air Temp (F)', 'Max Rel Hum (%)', 'Avg Wind Speed (mph)', 'Wind Run (miles)', 'Avg Soil Temp (F)']]
del_norte = del_norte_county[['Date', 'ETo (in)', 'Precip (in)', 'Sol Rad (Ly/day)', 'Avg Vap Pres (mBars)', 'Max Air Temp (F)', 'Min Air Temp (F)', 'Max Rel Hum (%)', 'Avg Wind Speed (mph)', 'Wind Run (miles)', 'Avg Soil Temp (F)']]
el_dorado = el_dorado_county[['Date', 'ETo (in)', 'Precip (in)', 'Sol Rad (Ly/day)', 'Avg Vap Pres (mBars)', 'Max Air Temp (F)', 'Min Air Temp (F)', 'Max Rel Hum (%)', 'Avg Wind Speed (mph)', 'Wind Run (miles)', 'Avg Soil Temp (F)']]
fresno = fresno_county[['Date', 'ETo (in)', 'Precip (in)', 'Sol Rad (Ly/day)', 'Avg Vap Pres (mBars)', 'Max Air Temp (F)', 'Min Air Temp (F)', 'Max Rel Hum (%)', 'Avg Wind Speed (mph)', 'Wind Run (miles)', 'Avg Soil Temp (F)']]
humboldt = humboldt_county[['Date', 'ETo (in)', 'Precip (in)', 'Sol Rad (Ly/day)', 'Avg Vap Pres (mBars)', 'Max Air Temp (F)', 'Min Air Temp (F)', 'Max Rel Hum (%)', 'Avg Wind Speed (mph)', 'Wind Run (miles)', 'Avg Soil Temp (F)']]
imperial = imperial_county[['Date', 'ETo (in)', 'Precip (in)', 'Sol Rad (Ly/day)', 'Avg Vap Pres (mBars)', 'Max Air Temp (F)', 'Min Air Temp (F)', 'Max Rel Hum (%)', 'Avg Wind Speed (mph)', 'Wind Run (miles)', 'Avg Soil Temp (F)']]
inyo = inyo_county[['Date', 'ETo (in)', 'Precip (in)', 'Sol Rad (Ly/day)', 'Avg Vap Pres (mBars)', 'Max Air Temp (F)', 'Min Air Temp (F)', 'Max Rel Hum (%)', 'Avg Wind Speed (mph)', 'Wind Run (miles)', 'Avg Soil Temp (F)']]
kern = kern_county[['Date', 'ETo (in)', 'Precip (in)', 'Sol Rad (Ly/day)', 'Avg Vap Pres (mBars)', 'Max Air Temp (F)', 'Min Air Temp (F)', 'Max Rel Hum (%)', 'Avg Wind Speed (mph)', 'Wind Run (miles)', 'Avg Soil Temp (F)']]
kings = kings_county[['Date', 'ETo (in)', 'Precip (in)', 'Sol Rad (Ly/day)', 'Avg Vap Pres (mBars)', 'Max Air Temp (F)', 'Min Air Temp (F)', 'Max Rel Hum (%)', 'Avg Wind Speed (mph)', 'Wind Run (miles)', 'Avg Soil Temp (F)']]
lassen = lassen_county[['Date', 'ETo (in)', 'Precip (in)', 'Sol Rad (Ly/day)', 'Avg Vap Pres (mBars)', 'Max Air Temp (F)', 'Min Air Temp (F)', 'Max Rel Hum (%)', 'Avg Wind Speed (mph)', 'Wind Run (miles)', 'Avg Soil Temp (F)']]
los_angeles = los_angeles_county[['Date', 'ETo (in)', 'Precip (in)', 'Sol Rad (Ly/day)', 'Avg Vap Pres (mBars)', 'Max Air Temp (F)', 'Min Air Temp (F)', 'Max Rel Hum (%)', 'Avg Wind Speed (mph)', 'Wind Run (miles)', 'Avg Soil Temp (F)']]
marin = marin_county[['Date', 'ETo (in)', 'Precip (in)', 'Sol Rad (Ly/day)', 'Avg Vap Pres (mBars)', 'Max Air Temp (F)', 'Min Air Temp (F)', 'Max Rel Hum (%)', 'Avg Wind Speed (mph)', 'Wind Run (miles)', 'Avg Soil Temp (F)']]
mendocino = mendocino_county[['Date', 'ETo (in)', 'Precip (in)', 'Sol Rad (Ly/day)', 'Avg Vap Pres (mBars)', 'Max Air Temp (F)', 'Min Air Temp (F)', 'Max Rel Hum (%)', 'Avg Wind Speed (mph)', 'Wind Run (miles)', 'Avg Soil Temp (F)']]
modoc = modoc_county[['Date', 'ETo (in)', 'Precip (in)', 'Sol Rad (Ly/day)', 'Avg Vap Pres (mBars)', 'Max Air Temp (F)', 'Min Air Temp (F)', 'Max Rel Hum (%)', 'Avg Wind Speed (mph)', 'Wind Run (miles)', 'Avg Soil Temp (F)']]
monterey = monterey_county[['Date', 'ETo (in)', 'Precip (in)', 'Sol Rad (Ly/day)', 'Avg Vap Pres (mBars)', 'Max Air Temp (F)', 'Min Air Temp (F)', 'Max Rel Hum (%)', 'Avg Wind Speed (mph)', 'Wind Run (miles)', 'Avg Soil Temp (F)']]
napa = napa_county[['Date', 'ETo (in)', 'Precip (in)', 'Sol Rad (Ly/day)', 'Avg Vap Pres (mBars)', 'Max Air Temp (F)', 'Min Air Temp (F)', 'Max Rel Hum (%)', 'Avg Wind Speed (mph)', 'Wind Run (miles)', 'Avg Soil Temp (F)']]
orange = orange_county[['Date', 'ETo (in)', 'Precip (in)', 'Sol Rad (Ly/day)', 'Avg Vap Pres (mBars)', 'Max Air Temp (F)', 'Min Air Temp (F)', 'Max Rel Hum (%)', 'Avg Wind Speed (mph)', 'Wind Run (miles)', 'Avg Soil Temp (F)']]
placer = placer_county[['Date', 'ETo (in)', 'Precip (in)', 'Sol Rad (Ly/day)', 'Avg Vap Pres (mBars)', 'Max Air Temp (F)', 'Min Air Temp (F)', 'Max Rel Hum (%)', 'Avg Wind Speed (mph)', 'Wind Run (miles)', 'Avg Soil Temp (F)']]
plumas = plumas_county[['Date', 'ETo (in)', 'Precip (in)', 'Sol Rad (Ly/day)', 'Avg Vap Pres (mBars)', 'Max Air Temp (F)', 'Min Air Temp (F)', 'Max Rel Hum (%)', 'Avg Wind Speed (mph)', 'Wind Run (miles)', 'Avg Soil Temp (F)']]
riverside = riverside_county[['Date', 'ETo (in)', 'Precip (in)', 'Sol Rad (Ly/day)', 'Avg Vap Pres (mBars)', 'Max Air Temp (F)', 'Min Air Temp (F)', 'Max Rel Hum (%)', 'Avg Wind Speed (mph)', 'Wind Run (miles)', 'Avg Soil Temp (F)']]
sacramento = sacramento_county[['Date', 'ETo (in)', 'Precip (in)', 'Sol Rad (Ly/day)', 'Avg Vap Pres (mBars)', 'Max Air Temp (F)', 'Min Air Temp (F)', 'Max Rel Hum (%)', 'Avg Wind Speed (mph)', 'Wind Run (miles)', 'Avg Soil Temp (F)']]
san_benito = san_benito_county[['Date', 'ETo (in)', 'Precip (in)', 'Sol Rad (Ly/day)', 'Avg Vap Pres (mBars)', 'Max Air Temp (F)', 'Min Air Temp (F)', 'Max Rel Hum (%)', 'Avg Wind Speed (mph)', 'Wind Run (miles)', 'Avg Soil Temp (F)']]
san_bernardino = san_bernardino_county[['Date', 'ETo (in)', 'Precip (in)', 'Sol Rad (Ly/day)', 'Avg Vap Pres (mBars)', 'Max Air Temp (F)', 'Min Air Temp (F)', 'Max Rel Hum (%)', 'Avg Wind Speed (mph)', 'Wind Run (miles)', 'Avg Soil Temp (F)']]
san_diego = san_diego_county[['Date', 'ETo (in)', 'Precip (in)', 'Sol Rad (Ly/day)', 'Avg Vap Pres (mBars)', 'Max Air Temp (F)', 'Min Air Temp (F)', 'Max Rel Hum (%)', 'Avg Wind Speed (mph)', 'Wind Run (miles)', 'Avg Soil Temp (F)']]
san_joaquin = san_joaquin_county[['Date', 'ETo (in)', 'Precip (in)', 'Sol Rad (Ly/day)', 'Avg Vap Pres (mBars)', 'Max Air Temp (F)', 'Min Air Temp (F)', 'Max Rel Hum (%)', 'Avg Wind Speed (mph)', 'Wind Run (miles)', 'Avg Soil Temp (F)']]
san_luis_obispo = san_luis_obispo_county[['Date', 'ETo (in)', 'Precip (in)', 'Sol Rad (Ly/day)', 'Avg Vap Pres (mBars)', 'Max Air Temp (F)', 'Min Air Temp (F)', 'Max Rel Hum (%)', 'Avg Wind Speed (mph)', 'Wind Run (miles)', 'Avg Soil Temp (F)']]
san_mateo = san_mateo_county[['Date', 'ETo (in)', 'Precip (in)', 'Sol Rad (Ly/day)', 'Avg Vap Pres (mBars)', 'Max Air Temp (F)', 'Min Air Temp (F)', 'Max Rel Hum (%)', 'Avg Wind Speed (mph)', 'Wind Run (miles)', 'Avg Soil Temp (F)']]
santa_barbara = santa_barbara_county[['Date', 'ETo (in)', 'Precip (in)', 'Sol Rad (Ly/day)', 'Avg Vap Pres (mBars)', 'Max Air Temp (F)', 'Min Air Temp (F)', 'Max Rel Hum (%)', 'Avg Wind Speed (mph)', 'Wind Run (miles)', 'Avg Soil Temp (F)']]
santa_clara = santa_clara_county[['Date', 'ETo (in)', 'Precip (in)', 'Sol Rad (Ly/day)', 'Avg Vap Pres (mBars)', 'Max Air Temp (F)', 'Min Air Temp (F)', 'Max Rel Hum (%)', 'Avg Wind Speed (mph)', 'Wind Run (miles)', 'Avg Soil Temp (F)']]
santa_cruz = santa_cruz_county[['Date', 'ETo (in)', 'Precip (in)', 'Sol Rad (Ly/day)', 'Avg Vap Pres (mBars)', 'Max Air Temp (F)', 'Min Air Temp (F)', 'Max Rel Hum (%)', 'Avg Wind Speed (mph)', 'Wind Run (miles)', 'Avg Soil Temp (F)']]
shasta = shasta_county[['Date', 'ETo (in)', 'Precip (in)', 'Sol Rad (Ly/day)', 'Avg Vap Pres (mBars)', 'Max Air Temp (F)', 'Min Air Temp (F)', 'Max Rel Hum (%)', 'Avg Wind Speed (mph)', 'Wind Run (miles)', 'Avg Soil Temp (F)']]
siskiyou = siskiyou_county[['Date', 'ETo (in)', 'Precip (in)', 'Sol Rad (Ly/day)', 'Avg Vap Pres (mBars)', 'Max Air Temp (F)', 'Min Air Temp (F)', 'Max Rel Hum (%)', 'Avg Wind Speed (mph)', 'Wind Run (miles)', 'Avg Soil Temp (F)']]
solano = solano_county[['Date', 'ETo (in)', 'Precip (in)', 'Sol Rad (Ly/day)', 'Avg Vap Pres (mBars)', 'Max Air Temp (F)', 'Min Air Temp (F)', 'Max Rel Hum (%)', 'Avg Wind Speed (mph)', 'Wind Run (miles)', 'Avg Soil Temp (F)']]
sonoma = sonoma_county[['Date', 'ETo (in)', 'Precip (in)', 'Sol Rad (Ly/day)', 'Avg Vap Pres (mBars)', 'Max Air Temp (F)', 'Min Air Temp (F)', 'Max Rel Hum (%)', 'Avg Wind Speed (mph)', 'Wind Run (miles)', 'Avg Soil Temp (F)']]
stanislaus = stanislaus_county[['Date', 'ETo (in)', 'Precip (in)', 'Sol Rad (Ly/day)', 'Avg Vap Pres (mBars)', 'Max Air Temp (F)', 'Min Air Temp (F)', 'Max Rel Hum (%)', 'Avg Wind Speed (mph)', 'Wind Run (miles)', 'Avg Soil Temp (F)']]
sutter = sutter_county[['Date', 'ETo (in)', 'Precip (in)', 'Sol Rad (Ly/day)', 'Avg Vap Pres (mBars)', 'Max Air Temp (F)', 'Min Air Temp (F)', 'Max Rel Hum (%)', 'Avg Wind Speed (mph)', 'Wind Run (miles)', 'Avg Soil Temp (F)']]
tehama = tehama_county[['Date', 'ETo (in)', 'Precip (in)', 'Sol Rad (Ly/day)', 'Avg Vap Pres (mBars)', 'Max Air Temp (F)', 'Min Air Temp (F)', 'Max Rel Hum (%)', 'Avg Wind Speed (mph)', 'Wind Run (miles)', 'Avg Soil Temp (F)']]
tulare = tulare_county[['Date', 'ETo (in)', 'Precip (in)', 'Sol Rad (Ly/day)', 'Avg Vap Pres (mBars)', 'Max Air Temp (F)', 'Min Air Temp (F)', 'Max Rel Hum (%)', 'Avg Wind Speed (mph)', 'Wind Run (miles)', 'Avg Soil Temp (F)']]
ventura = ventura_county[['Date', 'ETo (in)', 'Precip (in)', 'Sol Rad (Ly/day)', 'Avg Vap Pres (mBars)', 'Max Air Temp (F)', 'Min Air Temp (F)', 'Max Rel Hum (%)', 'Avg Wind Speed (mph)', 'Wind Run (miles)', 'Avg Soil Temp (F)']]
yolo = yolo_county[['Date', 'ETo (in)', 'Precip (in)', 'Sol Rad (Ly/day)', 'Avg Vap Pres (mBars)', 'Max Air Temp (F)', 'Min Air Temp (F)', 'Max Rel Hum (%)', 'Avg Wind Speed (mph)', 'Wind Run (miles)', 'Avg Soil Temp (F)']]
yuba = yuba_county[['Date', 'ETo (in)', 'Precip (in)', 'Sol Rad (Ly/day)', 'Avg Vap Pres (mBars)', 'Max Air Temp (F)', 'Min Air Temp (F)', 'Max Rel Hum (%)', 'Avg Wind Speed (mph)', 'Wind Run (miles)', 'Avg Soil Temp (F)']]

# %%
alameda['County'] = 'Alameda'
alpine['County'] = 'Alpine'
amador['County'] = 'Amador'
butte['County'] = 'Butte'
colusa['County'] = 'Colusa'
contra_costa_['County'] = 'Contra Costa'
del_norte['County'] = 'Del Norte'
el_dorado['County'] = 'El Dorado'
fresno['County'] = 'Fresno'
humboldt['County'] = 'Humboldt'
imperial['County'] = 'Imperial'
inyo['County'] = 'Inyo'
kern['County'] = 'Kern'
kings['County'] = 'Kings'
lassen['County'] = 'Lassen'
los_angeles['County'] = 'Los Angeles'
marin['County'] = 'Marin'
mendocino['County'] = 'Mendocino'
modoc['County'] = 'Modoc'
monterey['County'] = 'Monterey'
napa['County'] = 'Napa'
orange['County'] = 'Orange'
placer['County'] = 'Placer'
plumas['County'] = 'Plumas'
riverside['County'] = 'Riverside'
sacramento['County'] = 'Sacramento'
san_benito['County'] = 'San Benito'
san_bernardino['County'] = 'San Bernardino'
san_diego['County'] = 'San Diego'
san_joaquin['County'] = 'San Joaquin'
san_luis_obispo['County'] = 'San Luis Obispo'
san_mateo['County'] = 'San Mateo'
santa_barbara['County'] = 'Santa Barbara'
santa_clara['County'] = 'Santa Clara'
santa_cruz['County'] = 'Santa Cruz'
shasta['County'] = 'Shasta'
siskiyou['County'] = 'Siskiyou'
solano['County'] = 'Solano'
sonoma['County'] = 'Sonoma'
stanislaus['County'] = 'Stanislaus'
sutter['County'] = 'Sutter'
tehama['County'] = 'Tehama'
tulare['County'] = 'Tulare'
ventura['County'] = 'Ventura'
yolo['County'] = 'Yolo'
yuba['County'] = 'Yuba'
# Out:
# <ipython-input-23-7039f7d1bc93>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   alameda['County'] = 'Alameda'
# <ipython-input-23-7039f7d1bc93>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   alpine['County'] = 'Alpine'
# <ipython-input-23-7039f7d1bc93>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
alameda = alameda[['County'] + [col for col in alameda.columns if col != 'County']]
alpine = alpine[['County'] + [col for col in alpine.columns if col != 'County']]
amador = amador[['County'] + [col for col in amador.columns if col != 'County']]
butte = butte[['County'] + [col for col in butte.columns if col != 'County']]
colusa = colusa[['County'] + [col for col in colusa.columns if col != 'County']]
contra_costa_ = contra_costa_[['County'] + [col for col in contra_costa_.columns if col != 'County']]
del_norte = del_norte[['County'] + [col for col in del_norte.columns if col != 'County']]
el_dorado = el_dorado[['County'] + [col for col in el_dorado.columns if col != 'County']]
fresno = fresno[['County'] + [col for col in fresno.columns if col != 'County']]
humboldt = humboldt[['County'] + [col for col in humboldt.columns if col != 'County']]
imperial = imperial[['County'] + [col for col in imperial.columns if col != 'County']]
inyo = inyo[['County'] + [col for col in inyo.columns if col != 'County']]
kern = kern[['County'] + [col for col in kern.columns if col != 'County']]
kings = kings[['County'] + [col for col in kings.columns if col != 'County']]
lassen = lassen[['County'] + [col for col in lassen.columns if col != 'County']]
los_angeles = los_angeles[['County'] + [col for col in los_angeles.columns if col != 'County']]
marin = marin[['County'] + [col for col in marin.columns if col != 'County']]
mendocino = mendocino[['County'] + [col for col in mendocino.columns if col != 'County']]
modoc = modoc[['County'] + [col for col in modoc.columns if col != 'County']]
monterey = monterey[['County'] + [col for col in monterey.columns if col != 'County']]
napa = napa[['County'] + [col for col in napa.columns if col != 'County']]
orange = orange[['County'] + [col for col in orange.columns if col != 'County']]
placer = placer[['County'] + [col for col in placer.columns if col != 'County']]
plumas = plumas[['County'] + [col for col in plumas.columns if col != 'County']]
riverside = riverside[['County'] + [col for col in riverside.columns if col != 'County']]
sacramento = sacramento[['County'] + [col for col in sacramento.columns if col != 'County']]
san_benito = san_benito[['County'] + [col for col in san_benito.columns if col != 'County']]
san_bernardino = san_bernardino[['County'] + [col for col in san_bernardino.columns if col != 'County']]
san_diego = san_diego[['County'] + [col for col in san_diego.columns if col != 'County']]
san_joaquin = san_joaquin[['County'] + [col for col in san_joaquin.columns if col != 'County']]
san_luis_obispo = san_luis_obispo[['County'] + [col for col in san_luis_obispo.columns if col != 'County']]
san_mateo = san_mateo[['County'] + [col for col in san_mateo.columns if col != 'County']]
santa_barbara = santa_barbara[['County'] + [col for col in santa_barbara.columns if col != 'County']]
santa_clara = santa_clara[['County'] + [col for col in santa_clara.columns if col != 'County']]
santa_cruz = santa_cruz[['County'] + [col for col in santa_cruz.columns if col != 'County']]
shasta = shasta[['County'] + [col for col in shasta.columns if col != 'County']]
siskiyou = siskiyou[['County'] + [col for col in siskiyou.columns if col != 'County']]
solano = solano[['County'] + [col for col in solano.columns if col != 'County']]
sonoma = sonoma[['County'] + [col for col in sonoma.columns if col != 'County']]
stanislaus = stanislaus[['County'] + [col for col in stanislaus.columns if col != 'County']]
sutter = sutter[['County'] + [col for col in sutter.columns if col != 'County']]
tehama = tehama[['County'] + [col for col in tehama.columns if col != 'County']]
tulare = tulare[['County'] + [col for col in tulare.columns if col != 'County']]
ventura = ventura[['County'] + [col for col in ventura.columns if col != 'County']]
yolo = yolo[['County'] + [col for col in yolo.columns if col != 'County']]
yuba = yuba[['County'] + [col for col in yuba.columns if col != 'County']]

# %%
amador
# Out:
#       County        Date  ETo (in)  Precip (in)  Sol Rad (Ly/day)  \
# 0     Amador   11/1/2010      0.09         0.00             313.0
# 1     Amador   11/2/2010      0.09         0.00             307.0
# 2     Amador   11/3/2010      0.09         0.00             294.0
# 3     Amador   11/4/2010      0.09         0.00             298.0
# 4     Amador   11/5/2010      0.08         0.00             261.0
# ...      ...         ...       ...          ...               ...
# 5168  Amador  12/27/2024      0.01         0.28              90.0
# 5169  Amador  12/28/2024      0.01         0.09              80.0
# 5170  Amador  12/29/2024      0.00         0.59              58.0
# 5171  Amador  12/30/2024      0.05         0.00             229.0
# 5172  Amador  12/31/2024      0.00         0.00             231.0
#
#       Avg Vap Pres (mBars)  Max Air Temp (F)  Min Air Temp (F)  \
# 0                      9.5              69.2              38.2
# ...

# %%
alameda.to_csv('Alameda County.csv', index=False)
alpine.to_csv('Alpine County.csv', index=False)
amador.to_csv('Amador County.csv', index=False)
butte.to_csv('Butte County.csv', index=False)
colusa.to_csv('Colusa County.csv', index=False)
contra_costa_.to_csv('Contra Costa County.csv', index=False)
del_norte.to_csv('Del Norte County.csv', index=False)
el_dorado.to_csv('El Dorado County.csv', index=False)
fresno.to_csv('Fresno County.csv', index=False)
humboldt.to_csv('Humboldt County.csv', index=False)
humboldt.to_csv('Humboldt County.csv', index=False)
imperial.to_csv('Imperial County.csv', index=False)
inyo.to_csv('Inyo County.csv', index=False)
kern.to_csv('Kern County.csv', index=False)
kings.to_csv('Kings County.csv', index=False)
lassen.to_csv('Lassen County.csv', index=False)
los_angeles.to_csv('Los Angeles County.csv', index=False)
marin.to_csv('Marin County.csv', index=False)
mendocino.to_csv('Mendocino County.csv', index=False)
modoc.to_csv('Modoc County.csv', index=False)
monterey.to_csv('Monterey County.csv', index=False)
napa.to_csv('Napa County.csv', index=False)
orange.to_csv('Orange County.csv', index=False)
placer.to_csv('Placer County.csv', index=False)
plumas.to_csv('Plumas County.csv', index=False)
riverside.to_csv('Riverside County.csv', index=False)
sacramento.to_csv('Sacramento County.csv', index=False)
san_benito.to_csv('San Benito County.csv', index=False)
san_bernardino.to_csv('San Bernardino County.csv', index=False)
san_diego.to_csv('San Diego County.csv', index=False)
san_joaquin.to_csv('San Joaquin County.csv', index=False)
san_luis_obispo.to_csv('San Luis Obispo County.csv', index=False)
san_mateo.to_csv('San Mateo County.csv', index=False)
santa_barbara.to_csv('Santa Barbara County.csv', index=False)
santa_clara.to_csv('Santa Clara County.csv', index=False)
santa_cruz.to_csv('Santa Cruz County.csv', index=False)
shasta.to_csv('Shasta County.csv', index=False)
siskiyou.to_csv('Siskiyou County.csv', index=False)
solano.to_csv('Solano County.csv', index=False)
sonoma.to_csv('Sonoma County.csv', index=False)
stanislaus.to_csv('Stanislaus County.csv', index=False)
sutter.to_csv('Sutter County.csv', index=False)
tehama.to_csv('Tehama County.csv', index=False)
tulare.to_csv('Tulare County.csv', index=False)
ventura.to_csv('Ventura County.csv', index=False)
yolo.to_csv('Yolo County.csv', index=False)
yuba.to_csv('Yuba County.csv', index=False)
